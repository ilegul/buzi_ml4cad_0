# %%
# This notebook is used to
# 1. Refine the classifiers to mitigate data imbalance
# 2. Create ensemble classifier
# 3. Perform feature ablation

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import copy
from joblib import dump, load

plt.style.use('bmh')
mpl.rcParams.update({
    "grid.linestyle" : "dashed",
    "axes.facecolor" : "white",
    "axes.spines.top" : False,
    "axes.spines.right" : False,
    "legend.frameon" : False,
    "figure.figsize" : (8, 5),
    "figure.dpi" : 300,
})

# suppress sklearn deprecated warnings
import warnings
def warn(*args, **kwargs): pass
warnings.warn = warn

# %%
# TODO make test for dataset with creatina column
# Dataset without thyroid = 18 features (including survive7y)
# Dataset with thyroid = 27 features (including survive7y)
# With columns that have missing values, 23 and 32
# Default 18
n_features = 27
extra_path = n_features != 27 and n_features != 18
dropped_na_key = "dropped_na/"
mean_key = "mean/"
path = f"data/{n_features}features/{mean_key if extra_path else '' }"
path_models = f"models/{n_features}features/{mean_key if extra_path else '' }"
path_images = f"figures/{n_features}features/{mean_key if extra_path else '' }"
output_models = f"models_output/{n_features}features/{mean_key if extra_path else '' }"
print(path_models)
print(path)
# Out:
# models/27features/
# data/27features/

# %% [markdown]
# ### Sampling
# Oversample and undersample methods to mitigate data imbalance

# %%
# Load Data for sampling
df_train = pd.read_csv(f"{path}train.csv", index_col=0)
df_valid = pd.read_csv(f"{path}valid.csv", index_col=0)
df_test = pd.read_csv(f"{path}test.csv", index_col=0)
print(len(df_train)+len(df_valid)+len(df_test))
feat_names = list(df_train.columns)
train, valid, test = df_train.to_numpy(), df_valid.to_numpy(), df_test.to_numpy()
X_train, y_train = train[:, :-1], train[:, -1]
X_valid, y_valid = valid[:, :-1], valid[:, -1]
X_test, y_test = test[:, :-1], test[:, -1]

from utils import get_preprocess_std_num
preprocess_std = get_preprocess_std_num(feat_names)


# Preprocessed ready-to-use train and valid set
process_tmp = preprocess_std.fit(X_train)
X_train_std = process_tmp.transform(X_train)
X_valid_std = process_tmp.transform(X_valid)
# Out:
# 6667

# %%
from imblearn.over_sampling import SMOTE, BorderlineSMOTE, SVMSMOTE
from collections import Counter
from train import evaluate
from utils import datasetSampler
from functools import partial
from train import evaluate
from contextlib import redirect_stdout
# Over sample to 50/
overs = [
    ("smote", SMOTE(sampling_strategy=1.0, k_neighbors=1)),
    ("bordersmote", BorderlineSMOTE(sampling_strategy=1.0, k_neighbors=1)),
    ("svmsmote", SVMSMOTE(sampling_strategy=1.0, k_neighbors=1)), 
    # ADASYN(sampling_strategy=1.0, n_neighbors=1)
]

sampler = partial(
    datasetSampler,
    # missing parameters: model, overSampler, sampling_strategy
    X_train=X_train,
    y_train=y_train,
    X_valid=X_valid,
    y_valid=y_valid,
    useUnderSampler = False
)
random_ratio = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
name_models = ["lr", "svc", "knn", "rf", "adaboost", "nn", "gb", "xgb"]
for name in name_models:
    best_k = 0
    best_over = ""
    best_score = 0
    best_random = 0
    best_model = None
    file_name = ""
    sampling_method = ""
    best_X, best_y = None, None

    for r in random_ratio:
        print("-------------------------------------------------")
        print(f"{'Oversample':<20}{'Score':<20}Random {r} Name {name}")
        print("-------------------------------------------------")
        for underSampler in range(1,3):
            print(f"########## Changing sampling mode ##########")
            for name_over, over in overs:
                for k in range(2, 5):
                    model = load(path_models+f"{name}.joblib")
                    over.set_params(k_neighbors=k)
                    result = sampler(
                        model_name= name,
                        model = model,
                        overSampler = over,
                        sampling_strategy = r,
                        useUnderSampler = True if underSampler == 2 else False
                    )
                    score = result[0]
                    X_train_sample = result[1]
                    y_train_sample = result[2]
                    model = result[3]
                    if score > best_score:
                        best_k = k
                        best_over = name_over
                        best_score = score
                        best_random = r
                        best_model = copy.deepcopy(model)
                        sampling_method = "only oversampling" if underSampler == 1 else "undersampling + oversampling"
                        suffix = "_only_oversampling" if underSampler == 1 else "_sampling"
                        file_name = output_models.replace("models_output/", '').replace("/","") + suffix + ".txt"
                        best_X = X_train_sample
                        best_y = y_train_sample
                #in this case the score is the last score computed with k = 4
                print(f'{name_over:<20}{score:.3f}')

    # Save the dataset and model
    combination = f"_random_{best_over}_{name}"
    tmp = np.concatenate((best_X, np.expand_dims(best_y, 1)), axis=1)
    tmp = pd.DataFrame(tmp, columns=feat_names)

    # Current model's statistics
    print("\n")
    print(f"Name model:      \t{name}")
    print(f"Sampling method: {sampling_method }")
    print(f"Best rand_ratio: \t{best_random}")
    print(f"Best score:      \t{best_score}")
    print(f"Dataset size:    \t{len(best_y)}, {Counter(best_y)}")
    print(f"Combination:     \t{combination}")
    print("\n\n")

    # Evaluate the best model, save the data and the best model
    evaluate(best_model, best_X, best_y)
    evaluate(best_model, X_valid, y_valid)
    tmp.to_csv(path+f"train{combination}.csv")
    dump(best_model, path_models+f"{name}{combination}.joblib")
    with open(f"{output_models}{file_name}", 'a+') as f:
            with redirect_stdout(f):
                print (f"####################   {name}    #########################")
                print("Testing on training set:")
                evaluate(best_model, best_X, best_y)
                print("Testing on validation set:")
                evaluate(best_model, X_valid, y_valid)
                print("Parameters: {0}".format(model.get_params()))
                print (f"####################   {name}  END   #########################")
# Out:
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.656
# bordersmote         0.620
# svmsmote            0.687
# ########## Changing sampling mode ##########
# smote               0.627
# bordersmote         0.646
# svmsmote            0.689
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.626
# bordersmote         0.635
# svmsmote            0.698
# ########## Changing sampling mode ##########
# smote               0.664
# bordersmote         0.615
# svmsmote            0.650
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.624
# bordersmote         0.642
# svmsmote            0.670
# ########## Changing sampling mode ##########
# smote               0.663
# bordersmote         0.634
# svmsmote            0.656
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.623
# bordersmote         0.637
# svmsmote            0.681
# ########## Changing sampling mode ##########
# smote               0.618
# bordersmote         0.600
# svmsmote            0.643
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.634
# bordersmote         0.635
# svmsmote            0.659
# ########## Changing sampling mode ##########
# smote               0.582
# bordersmote         0.632
# svmsmote            0.625
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.652
# bordersmote         0.656
# svmsmote            0.659
# ########## Changing sampling mode ##########
# smote               0.612
# bordersmote         0.638
# svmsmote            0.639
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.621
# bordersmote         0.633
# svmsmote            0.666
# ########## Changing sampling mode ##########
# smote               0.621
# bordersmote         0.597
# svmsmote            0.629
#
#
# Name model:      	lr
# Sampling method: only oversampling
# Best rand_ratio: 	0.25
# Best score:      	0.6976872907447327
# Dataset size:    	6988, Counter({np.float64(1.0): 3494, np.float64(0.0): 3494})
# Combination:     	_random_svmsmote_lr
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.868     0.834     0.851      3494
#          1.0      0.840     0.873     0.856      3494
#
#     accuracy                          0.854      6988
#    macro avg      0.854     0.854     0.854      6988
# weighted avg      0.854     0.854     0.854      6988
#
# auc macro 0.932
# confusion matrix
# [[2914  580]
#  [ 443 3051]]
#               precision    recall  f1-score   support
#
#          0.0      0.404     0.669     0.503       169
#          1.0      0.947     0.857     0.900      1165
#
#     accuracy                          0.833      1334
#    macro avg      0.675     0.763     0.701      1334
# weighted avg      0.878     0.833     0.849      1334
#
# auc macro 0.834
# confusion matrix
# [[113  56]
#  [167 998]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.559
# bordersmote         0.556
# svmsmote            0.563
# ########## Changing sampling mode ##########
# smote               0.651
# bordersmote         0.499
# svmsmote            0.555
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.607
# bordersmote         0.615
# svmsmote            0.444
# ########## Changing sampling mode ##########
# smote               0.542
# bordersmote         0.600
# svmsmote            0.599
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.498
# bordersmote         0.544
# svmsmote            0.568
# ########## Changing sampling mode ##########
# smote               0.652
# bordersmote         0.635
# svmsmote            0.593
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.588
# bordersmote         0.434
# svmsmote            0.483
# ########## Changing sampling mode ##########
# smote               0.637
# bordersmote         0.584
# svmsmote            0.621
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.347
# bordersmote         0.585
# svmsmote            0.582
# ########## Changing sampling mode ##########
# smote               0.612
# bordersmote         0.584
# svmsmote            0.624
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.597
# bordersmote         0.661
# svmsmote            0.619
# ########## Changing sampling mode ##########
# smote               0.623
# bordersmote         0.669
# svmsmote            0.644
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.544
# bordersmote         0.569
# svmsmote            0.510
# ########## Changing sampling mode ##########
# smote               0.663
# bordersmote         0.526
# svmsmote            0.657
#
#
# Name model:      	svc
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.4
# Best score:      	0.6723574142655564
# Dataset size:    	2524, Counter({np.float64(0.0): 1262, np.float64(1.0): 1262})
# Combination:     	_random_smote_svc
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.839     0.659     0.738      1262
#          1.0      0.719     0.873     0.789      1262
#
#     accuracy                          0.766      2524
#    macro avg      0.779     0.766     0.764      2524
# weighted avg      0.779     0.766     0.764      2524
#
# auc macro 0.869
# confusion matrix
# [[ 832  430]
#  [ 160 1102]]
#               precision    recall  f1-score   support
#
#          0.0      0.359     0.645     0.461       169
#          1.0      0.942     0.833     0.884      1165
#
#     accuracy                          0.809      1334
#    macro avg      0.650     0.739     0.672      1334
# weighted avg      0.868     0.809     0.830      1334
#
# auc macro 0.815
# confusion matrix
# [[109  60]
#  [195 970]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.568
# bordersmote         0.586
# svmsmote            0.597
# ########## Changing sampling mode ##########
# smote               0.544
# bordersmote         0.571
# svmsmote            0.583
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.566
# bordersmote         0.579
# svmsmote            0.608
# ########## Changing sampling mode ##########
# smote               0.549
# bordersmote         0.558
# svmsmote            0.583
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.565
# bordersmote         0.585
# svmsmote            0.586
# ########## Changing sampling mode ##########
# smote               0.538
# bordersmote         0.535
# svmsmote            0.557
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.556
# bordersmote         0.587
# svmsmote            0.602
# ########## Changing sampling mode ##########
# smote               0.537
# bordersmote         0.531
# svmsmote            0.586
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.576
# bordersmote         0.589
# svmsmote            0.597
# ########## Changing sampling mode ##########
# smote               0.520
# bordersmote         0.523
# svmsmote            0.543
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.563
# bordersmote         0.585
# svmsmote            0.600
# ########## Changing sampling mode ##########
# smote               0.514
# bordersmote         0.504
# svmsmote            0.530
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.560
# bordersmote         0.586
# svmsmote            0.605
# ########## Changing sampling mode ##########
# smote               0.530
# bordersmote         0.503
# svmsmote            0.518
#
#
# Name model:      	knn
# Sampling method: only oversampling
# Best rand_ratio: 	0.35
# Best score:      	0.6174832544108402
# Dataset size:    	6988, Counter({np.float64(1.0): 3494, np.float64(0.0): 3494})
# Combination:     	_random_svmsmote_knn
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.873     0.980     0.923      3494
#          1.0      0.977     0.857     0.913      3494
#
#     accuracy                          0.918      6988
#    macro avg      0.925     0.918     0.918      6988
# weighted avg      0.925     0.918     0.918      6988
#
# auc macro 0.993
# confusion matrix
# [[3424   70]
#  [ 500 2994]]
#               precision    recall  f1-score   support
#
#          0.0      0.285     0.580     0.382       169
#          1.0      0.928     0.789     0.853      1165
#
#     accuracy                          0.762      1334
#    macro avg      0.607     0.684     0.617      1334
# weighted avg      0.847     0.762     0.793      1334
#
# auc macro 0.714
# confusion matrix
# [[ 98  71]
#  [246 919]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.658
# bordersmote         0.666
# svmsmote            0.692
# ########## Changing sampling mode ##########
# smote               0.692
# bordersmote         0.688
# svmsmote            0.706
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.656
# bordersmote         0.665
# svmsmote            0.675
# ########## Changing sampling mode ##########
# smote               0.695
# bordersmote         0.701
# svmsmote            0.709
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.670
# bordersmote         0.658
# svmsmote            0.683
# ########## Changing sampling mode ##########
# smote               0.712
# bordersmote         0.706
# svmsmote            0.718
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.668
# bordersmote         0.663
# svmsmote            0.683
# ########## Changing sampling mode ##########
# smote               0.709
# bordersmote         0.706
# svmsmote            0.713
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.663
# bordersmote         0.665
# svmsmote            0.678
# ########## Changing sampling mode ##########
# smote               0.708
# bordersmote         0.706
# svmsmote            0.712
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.661
# bordersmote         0.660
# svmsmote            0.683
# ########## Changing sampling mode ##########
# smote               0.702
# bordersmote         0.697
# svmsmote            0.698
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.660
# bordersmote         0.657
# svmsmote            0.682
# ########## Changing sampling mode ##########
# smote               0.697
# bordersmote         0.689
# svmsmote            0.677
#
#
# Name model:      	rf
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.3
# Best score:      	0.726623539448263
# Dataset size:    	3366, Counter({np.float64(0.0): 1683, np.float64(1.0): 1683})
# Combination:     	_random_smote_rf
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.973     0.932     0.952      1683
#          1.0      0.934     0.974     0.954      1683
#
#     accuracy                          0.953      3366
#    macro avg      0.954     0.953     0.953      3366
# weighted avg      0.954     0.953     0.953      3366
#
# auc macro 0.993
# confusion matrix
# [[1568  115]
#  [  43 1640]]
#               precision    recall  f1-score   support
#
#          0.0      0.478     0.574     0.522       169
#          1.0      0.936     0.909     0.922      1165
#
#     accuracy                          0.867      1334
#    macro avg      0.707     0.741     0.722      1334
# weighted avg      0.878     0.867     0.872      1334
#
# auc macro 0.830
# confusion matrix
# [[  97   72]
#  [ 106 1059]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.692
# bordersmote         0.707
# svmsmote            0.689
# ########## Changing sampling mode ##########
# smote               0.711
# bordersmote         0.695
# svmsmote            0.708
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.701
# bordersmote         0.707
# svmsmote            0.682
# ########## Changing sampling mode ##########
# smote               0.717
# bordersmote         0.708
# svmsmote            0.701
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.681
# bordersmote         0.690
# svmsmote            0.684
# ########## Changing sampling mode ##########
# smote               0.708
# bordersmote         0.713
# svmsmote            0.657
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.678
# bordersmote         0.688
# svmsmote            0.692
# ########## Changing sampling mode ##########
# smote               0.705
# bordersmote         0.680
# svmsmote            0.674
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.687
# bordersmote         0.687
# svmsmote            0.689
# ########## Changing sampling mode ##########
# smote               0.705
# bordersmote         0.709
# svmsmote            0.659
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.699
# bordersmote         0.689
# svmsmote            0.694
# ########## Changing sampling mode ##########
# smote               0.694
# bordersmote         0.697
# svmsmote            0.645
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.694
# bordersmote         0.707
# svmsmote            0.696
# ########## Changing sampling mode ##########
# smote               0.683
# bordersmote         0.670
# svmsmote            0.669
#
#
# Name model:      	adaboost
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.35
# Best score:      	0.7235500340915801
# Dataset size:    	2884, Counter({np.float64(0.0): 1442, np.float64(1.0): 1442})
# Combination:     	_random_bordersmote_adaboost
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.901     0.836     0.867      1442
#          1.0      0.847     0.908     0.876      1442
#
#     accuracy                          0.872      2884
#    macro avg      0.874     0.872     0.872      2884
# weighted avg      0.874     0.872     0.872      2884
#
# auc macro 0.944
# confusion matrix
# [[1206  236]
#  [ 133 1309]]
#               precision    recall  f1-score   support
#
#          0.0      0.451     0.651     0.533       169
#          1.0      0.946     0.885     0.914      1165
#
#     accuracy                          0.855      1334
#    macro avg      0.698     0.768     0.724      1334
# weighted avg      0.883     0.855     0.866      1334
#
# auc macro 0.841
# confusion matrix
# [[ 110   59]
#  [ 134 1031]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.650
# bordersmote         0.642
# svmsmote            0.707
# ########## Changing sampling mode ##########
# smote               0.646
# bordersmote         0.644
# svmsmote            0.696
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.639
# bordersmote         0.643
# svmsmote            0.674
# ########## Changing sampling mode ##########
# smote               0.645
# bordersmote         0.641
# svmsmote            0.680
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.646
# bordersmote         0.647
# svmsmote            0.674
# ########## Changing sampling mode ##########
# smote               0.655
# bordersmote         0.617
# svmsmote            0.672
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.648
# bordersmote         0.658
# svmsmote            0.707
# ########## Changing sampling mode ##########
# smote               0.618
# bordersmote         0.622
# svmsmote            0.653
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.648
# bordersmote         0.645
# svmsmote            0.696
# ########## Changing sampling mode ##########
# smote               0.642
# bordersmote         0.589
# svmsmote            0.644
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.648
# bordersmote         0.646
# svmsmote            0.676
# ########## Changing sampling mode ##########
# smote               0.649
# bordersmote         0.614
# svmsmote            0.605
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.648
# bordersmote         0.653
# svmsmote            0.698
# ########## Changing sampling mode ##########
# smote               0.651
# bordersmote         0.610
# svmsmote            0.628
#
#
# Name model:      	nn
# Sampling method: only oversampling
# Best rand_ratio: 	0.2
# Best score:      	0.7073089620433215
# Dataset size:    	6988, Counter({np.float64(1.0): 3494, np.float64(0.0): 3494})
# Combination:     	_random_svmsmote_nn
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.890     0.857     0.873      3494
#          1.0      0.862     0.894     0.878      3494
#
#     accuracy                          0.876      6988
#    macro avg      0.876     0.876     0.875      6988
# weighted avg      0.876     0.876     0.875      6988
#
# auc macro 0.948
# confusion matrix
# [[2993  501]
#  [ 369 3125]]
#               precision    recall  f1-score   support
#
#          0.0      0.427     0.627     0.508       169
#          1.0      0.942     0.878     0.909      1165
#
#     accuracy                          0.846      1334
#    macro avg      0.685     0.753     0.709      1334
# weighted avg      0.877     0.846     0.858      1334
#
# auc macro 0.833
# confusion matrix
# [[ 106   63]
#  [ 142 1023]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.686
# bordersmote         0.686
# svmsmote            0.706
# ########## Changing sampling mode ##########
# smote               0.700
# bordersmote         0.708
# svmsmote            0.708
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.686
# bordersmote         0.680
# svmsmote            0.694
# ########## Changing sampling mode ##########
# smote               0.707
# bordersmote         0.714
# svmsmote            0.703
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.680
# bordersmote         0.688
# svmsmote            0.699
# ########## Changing sampling mode ##########
# smote               0.706
# bordersmote         0.709
# svmsmote            0.702
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.684
# bordersmote         0.681
# svmsmote            0.702
# ########## Changing sampling mode ##########
# smote               0.706
# bordersmote         0.698
# svmsmote            0.704
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.685
# bordersmote         0.679
# svmsmote            0.697
# ########## Changing sampling mode ##########
# smote               0.702
# bordersmote         0.695
# svmsmote            0.697
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.688
# bordersmote         0.681
# svmsmote            0.699
# ########## Changing sampling mode ##########
# smote               0.699
# bordersmote         0.690
# svmsmote            0.698
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.677
# bordersmote         0.677
# svmsmote            0.698
# ########## Changing sampling mode ##########
# smote               0.683
# bordersmote         0.681
# svmsmote            0.676
#
#
# Name model:      	gb
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.25
# Best score:      	0.7167031705400279
# Dataset size:    	4040, Counter({np.float64(0.0): 2020, np.float64(1.0): 2020})
# Combination:     	_random_svmsmote_gb
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.918     0.883     0.900      2020
#          1.0      0.887     0.921     0.904      2020
#
#     accuracy                          0.902      4040
#    macro avg      0.903     0.902     0.902      4040
# weighted avg      0.903     0.902     0.902      4040
#
# auc macro 0.963
# confusion matrix
# [[1783  237]
#  [ 159 1861]]
#               precision    recall  f1-score   support
#
#          0.0      0.468     0.598     0.525       169
#          1.0      0.939     0.901     0.920      1165
#
#     accuracy                          0.863      1334
#    macro avg      0.703     0.749     0.722      1334
# weighted avg      0.879     0.863     0.870      1334
#
# auc macro 0.844
# confusion matrix
# [[ 101   68]
#  [ 115 1050]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.706
# bordersmote         0.698
# svmsmote            0.693
# ########## Changing sampling mode ##########
# smote               0.688
# bordersmote         0.676
# svmsmote            0.679
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.712
# bordersmote         0.695
# svmsmote            0.708
# ########## Changing sampling mode ##########
# smote               0.657
# bordersmote         0.657
# svmsmote            0.644
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.693
# bordersmote         0.708
# svmsmote            0.694
# ########## Changing sampling mode ##########
# smote               0.660
# bordersmote         0.655
# svmsmote            0.643
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.688
# bordersmote         0.697
# svmsmote            0.692
# ########## Changing sampling mode ##########
# smote               0.635
# bordersmote         0.632
# svmsmote            0.632
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.707
# bordersmote         0.688
# svmsmote            0.697
# ########## Changing sampling mode ##########
# smote               0.626
# bordersmote         0.608
# svmsmote            0.608
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.697
# bordersmote         0.691
# svmsmote            0.692
# ########## Changing sampling mode ##########
# smote               0.613
# bordersmote         0.597
# svmsmote            0.593
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.705
# bordersmote         0.689
# svmsmote            0.681
# ########## Changing sampling mode ##########
# smote               0.594
# bordersmote         0.574
# svmsmote            0.576
#
#
# Name model:      	xgb
# Sampling method: only oversampling
# Best rand_ratio: 	0.4
# Best score:      	0.7127476313522825
# Dataset size:    	6988, Counter({np.float64(1.0): 3494, np.float64(0.0): 3494})
# Combination:     	_random_bordersmote_xgb
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.889     0.947     0.917      3494
#          1.0      0.943     0.882     0.912      3494
#
#     accuracy                          0.914      6988
#    macro avg      0.916     0.914     0.914      6988
# weighted avg      0.916     0.914     0.914      6988
#
# auc macro 0.977
# confusion matrix
# [[3309  185]
#  [ 413 3081]]
#               precision    recall  f1-score   support
#
#          0.0      0.426     0.663     0.519       169
#          1.0      0.947     0.870     0.907      1165
#
#     accuracy                          0.844      1334
#    macro avg      0.686     0.767     0.713      1334
# weighted avg      0.881     0.844     0.858      1334
#
# auc macro 0.841
# confusion matrix
# [[ 112   57]
#  [ 151 1014]]

# %%
from auto_export_notebook import export_current_notebook


html_path = export_current_notebook(
    globals(),
    wait_for_disk_save=True,   # wait for Auto Save
    wait_timeout_sec=8.0
)
print("Exported to:", html_path)
# Out:
# Exported to: /home/ileniag/buzi_ml4cad_0/exported_notebooks/3.1_data_sampling_27features_20250929_232726.html
