# %%
# This notebook is used to
# 1. Refine the classifiers to mitigate data imbalance
# 2. Create ensemble classifier
# 3. Perform feature ablation

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import copy
from joblib import dump, load

plt.style.use('bmh')
mpl.rcParams.update({
    "grid.linestyle" : "dashed",
    "axes.facecolor" : "white",
    "axes.spines.top" : False,
    "axes.spines.right" : False,
    "legend.frameon" : False,
    "figure.figsize" : (8, 5),
    "figure.dpi" : 300,
})

# suppress sklearn deprecated warnings
import warnings
def warn(*args, **kwargs): pass
warnings.warn = warn

# %%
# TODO make test for dataset with creatina column
# Dataset without thyroid = 18 features (including survive7y)
# Dataset with thyroid = 27 features (including survive7y)
# With columns that have missing values, 23 and 32
# Default 18
n_features = 27
extra_path = n_features != 27 and n_features != 18
dropped_na_key = "dropped_na/"
mean_key = "mean/"
path = f"data/{n_features}features/{mean_key if extra_path else '' }"
path_models = f"models/{n_features}features/{mean_key if extra_path else '' }"
path_images = f"figures/{n_features}features/{mean_key if extra_path else '' }"
output_models = f"models_output/{n_features}features/{mean_key if extra_path else '' }"
print(path_models)
print(path)
# Out:
# models/27features/
# data/27features/

# %% [markdown]
# ### Sampling
# Oversample and undersample methods to mitigate data imbalance

# %%
# Load Data for sampling
df_train = pd.read_csv(f"{path}train.csv", index_col=0)
df_valid = pd.read_csv(f"{path}valid.csv", index_col=0)
df_test = pd.read_csv(f"{path}test.csv", index_col=0)
print(len(df_train)+len(df_valid)+len(df_test))
feat_names = list(df_train.columns)
train, valid, test = df_train.to_numpy(), df_valid.to_numpy(), df_test.to_numpy()
X_train, y_train = train[:, :-1], train[:, -1]
X_valid, y_valid = valid[:, :-1], valid[:, -1]
X_test, y_test = test[:, :-1], test[:, -1]

from utils import get_preprocess_std_num
preprocess_std = get_preprocess_std_num(feat_names)


# Preprocessed ready-to-use train and valid set
process_tmp = preprocess_std.fit(X_train)
X_train_std = process_tmp.transform(X_train)
X_valid_std = process_tmp.transform(X_valid)
# Out:
# 6667

# %%
from imblearn.over_sampling import SMOTE, BorderlineSMOTE, SVMSMOTE
from collections import Counter
from train import evaluate
from utils import datasetSampler
from functools import partial
from train import evaluate
from contextlib import redirect_stdout
# Over sample to 50/
overs = [
    ("smote", SMOTE(sampling_strategy=1.0, k_neighbors=1)),
    ("bordersmote", BorderlineSMOTE(sampling_strategy=1.0, k_neighbors=1)),
    ("svmsmote", SVMSMOTE(sampling_strategy=1.0, k_neighbors=1)), 
    # ADASYN(sampling_strategy=1.0, n_neighbors=1)
]

sampler = partial(
    datasetSampler,
    # missing parameters: model, overSampler, sampling_strategy
    X_train=X_train,
    y_train=y_train,
    X_valid=X_valid,
    y_valid=y_valid,
    useUnderSampler = False
)
random_ratio = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
name_models = ["lr", "svc", "knn", "rf", "adaboost", "nn", "gb", "xgb"]
for name in name_models:
    best_k = 0
    best_over = ""
    best_score = 0
    best_random = 0
    best_model = None
    file_name = ""
    sampling_method = ""
    best_X, best_y = None, None

    for r in random_ratio:
        print("-------------------------------------------------")
        print(f"{'Oversample':<20}{'Score':<20}Random {r} Name {name}")
        print("-------------------------------------------------")
        for underSampler in range(1,3):
            print(f"########## Changing sampling mode ##########")
            for name_over, over in overs:
                for k in range(2, 5):
                    model = load(path_models+f"{name}.joblib")
                    over.set_params(k_neighbors=k)
                    result = sampler(
                        model_name= name,
                        model = model,
                        overSampler = over,
                        sampling_strategy = r,
                        useUnderSampler = True if underSampler == 2 else False
                    )
                    score = result[0]
                    X_train_sample = result[1]
                    y_train_sample = result[2]
                    model = result[3]
                    if score > best_score:
                        best_k = k
                        best_over = name_over
                        best_score = score
                        best_random = r
                        best_model = copy.deepcopy(model)
                        sampling_method = "only oversampling" if underSampler == 1 else "undersampling + oversampling"
                        suffix = "_only_oversampling" if underSampler == 1 else "_sampling"
                        file_name = output_models.replace("models_output/", '').replace("/","") + suffix + ".txt"
                        best_X = X_train_sample
                        best_y = y_train_sample
                #in this case the score is the last score computed with k = 4
                print(f'{name_over:<20}{score:.3f}')

    # Save the dataset and model
    combination = f"_random_{best_over}_{name}"
    tmp = np.concatenate((best_X, np.expand_dims(best_y, 1)), axis=1)
    tmp = pd.DataFrame(tmp, columns=feat_names)

    # Current model's statistics
    print("\n")
    print(f"Name model:      \t{name}")
    print(f"Sampling method: {sampling_method }")
    print(f"Best rand_ratio: \t{best_random}")
    print(f"Best score:      \t{best_score}")
    print(f"Dataset size:    \t{len(best_y)}, {Counter(best_y)}")
    print(f"Combination:     \t{combination}")
    print("\n\n")

    # Evaluate the best model, save the data and the best model
    evaluate(best_model, best_X, best_y)
    evaluate(best_model, X_valid, y_valid)
    tmp.to_csv(path+f"train{combination}.csv")
    dump(best_model, path_models+f"{name}{combination}.joblib")
    with open(f"{output_models}{file_name}", 'a+') as f:
            with redirect_stdout(f):
                print (f"####################   {name}    #########################")
                print("Testing on training set:")
                evaluate(best_model, best_X, best_y)
                print("Testing on validation set:")
                evaluate(best_model, X_valid, y_valid)
                print("Parameters: {0}".format(model.get_params()))
                print (f"####################   {name}  END   #########################")
# Out:
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.584
# bordersmote         0.628
# svmsmote            0.651
# ########## Changing sampling mode ##########
# smote               0.589
# bordersmote         0.625
# svmsmote            0.659
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.601
# bordersmote         0.625
# svmsmote            0.660
# ########## Changing sampling mode ##########
# smote               0.645
# bordersmote         0.640
# svmsmote            0.627
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.636
# bordersmote         0.631
# svmsmote            0.643
# ########## Changing sampling mode ##########
# smote               0.603
# bordersmote         0.639
# svmsmote            0.638
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.630
# bordersmote         0.639
# svmsmote            0.659
# ########## Changing sampling mode ##########
# smote               0.624
# bordersmote         0.625
# svmsmote            0.622
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.605
# bordersmote         0.624
# svmsmote            0.658
# ########## Changing sampling mode ##########
# smote               0.612
# bordersmote         0.568
# svmsmote            0.629
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.654
# bordersmote         0.646
# svmsmote            0.654
# ########## Changing sampling mode ##########
# smote               0.597
# bordersmote         0.566
# svmsmote            0.615
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.637
# bordersmote         0.645
# svmsmote            0.652
# ########## Changing sampling mode ##########
# smote               0.655
# bordersmote         0.549
# svmsmote            0.644
#
#
# Name model:      	lr
# Sampling method: only oversampling
# Best rand_ratio: 	0.35
# Best score:      	0.6662518443285331
# Dataset size:    	6988, Counter({np.float64(1.0): 3494, np.float64(0.0): 3494})
# Combination:     	_random_svmsmote_lr
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.833     0.820     0.827      3494
#          1.0      0.823     0.836     0.829      3494
#
#     accuracy                          0.828      6988
#    macro avg      0.828     0.828     0.828      6988
# weighted avg      0.828     0.828     0.828      6988
#
# auc macro 0.909
# confusion matrix
# [[2865  629]
#  [ 573 2921]]
#               precision    recall  f1-score   support
#
#          0.0      0.349     0.651     0.455       169
#          1.0      0.942     0.824     0.879      1165
#
#     accuracy                          0.802      1334
#    macro avg      0.646     0.737     0.667      1334
# weighted avg      0.867     0.802     0.825      1334
#
# auc macro 0.818
# confusion matrix
# [[110  59]
#  [205 960]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.634
# bordersmote         0.498
# svmsmote            0.600
# ########## Changing sampling mode ##########
# smote               0.575
# bordersmote         0.570
# svmsmote            0.510
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.551
# bordersmote         0.520
# svmsmote            0.597
# ########## Changing sampling mode ##########
# smote               0.583
# bordersmote         0.562
# svmsmote            0.470
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.427
# bordersmote         0.470
# svmsmote            0.488
# ########## Changing sampling mode ##########
# smote               0.575
# bordersmote         0.592
# svmsmote            0.492
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.580
# bordersmote         0.528
# svmsmote            0.589
# ########## Changing sampling mode ##########
# smote               0.603
# bordersmote         0.553
# svmsmote            0.603
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.457
# bordersmote         0.553
# svmsmote            0.366
# ########## Changing sampling mode ##########
# smote               0.468
# bordersmote         0.541
# svmsmote            0.610
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.520
# bordersmote         0.563
# svmsmote            0.564
# ########## Changing sampling mode ##########
# smote               0.606
# bordersmote         0.555
# svmsmote            0.611
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.402
# bordersmote         0.544
# svmsmote            0.552
# ########## Changing sampling mode ##########
# smote               0.642
# bordersmote         0.616
# svmsmote            0.641
#
#
# Name model:      	svc
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.5
# Best score:      	0.6422646737855182
# Dataset size:    	2020, Counter({np.float64(0.0): 1010, np.float64(1.0): 1010})
# Combination:     	_random_smote_svc
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.819     0.708     0.759      1010
#          1.0      0.743     0.844     0.790      1010
#
#     accuracy                          0.776      2020
#    macro avg      0.781     0.776     0.775      2020
# weighted avg      0.781     0.776     0.775      2020
#
# auc macro 0.871
# confusion matrix
# [[715 295]
#  [158 852]]
#               precision    recall  f1-score   support
#
#          0.0      0.317     0.609     0.417       169
#          1.0      0.935     0.809     0.868      1165
#
#     accuracy                          0.784      1334
#    macro avg      0.626     0.709     0.642      1334
# weighted avg      0.856     0.784     0.810      1334
#
# auc macro 0.792
# confusion matrix
# [[103  66]
#  [222 943]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.564
# bordersmote         0.582
# svmsmote            0.595
# ########## Changing sampling mode ##########
# smote               0.550
# bordersmote         0.559
# svmsmote            0.586
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.557
# bordersmote         0.574
# svmsmote            0.593
# ########## Changing sampling mode ##########
# smote               0.529
# bordersmote         0.551
# svmsmote            0.566
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.563
# bordersmote         0.580
# svmsmote            0.596
# ########## Changing sampling mode ##########
# smote               0.521
# bordersmote         0.546
# svmsmote            0.572
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.559
# bordersmote         0.589
# svmsmote            0.606
# ########## Changing sampling mode ##########
# smote               0.535
# bordersmote         0.532
# svmsmote            0.564
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.564
# bordersmote         0.570
# svmsmote            0.580
# ########## Changing sampling mode ##########
# smote               0.528
# bordersmote         0.522
# svmsmote            0.550
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.555
# bordersmote         0.572
# svmsmote            0.588
# ########## Changing sampling mode ##########
# smote               0.518
# bordersmote         0.528
# svmsmote            0.582
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.552
# bordersmote         0.582
# svmsmote            0.582
# ########## Changing sampling mode ##########
# smote               0.523
# bordersmote         0.514
# svmsmote            0.516
#
#
# Name model:      	knn
# Sampling method: only oversampling
# Best rand_ratio: 	0.35
# Best score:      	0.6101026294419086
# Dataset size:    	6988, Counter({np.float64(1.0): 3494, np.float64(0.0): 3494})
# Combination:     	_random_svmsmote_knn
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.857     0.987     0.917      3494
#          1.0      0.985     0.835     0.904      3494
#
#     accuracy                          0.911      6988
#    macro avg      0.921     0.911     0.911      6988
# weighted avg      0.921     0.911     0.911      6988
#
# auc macro 0.993
# confusion matrix
# [[3449   45]
#  [ 576 2918]]
#               precision    recall  f1-score   support
#
#          0.0      0.275     0.598     0.377       169
#          1.0      0.930     0.772     0.843      1165
#
#     accuracy                          0.750      1334
#    macro avg      0.602     0.685     0.610      1334
# weighted avg      0.847     0.750     0.784      1334
#
# auc macro 0.733
# confusion matrix
# [[101  68]
#  [266 899]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.615
# bordersmote         0.614
# svmsmote            0.629
# ########## Changing sampling mode ##########
# smote               0.634
# bordersmote         0.644
# svmsmote            0.631
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.621
# bordersmote         0.618
# svmsmote            0.635
# ########## Changing sampling mode ##########
# smote               0.648
# bordersmote         0.658
# svmsmote            0.651
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.620
# bordersmote         0.621
# svmsmote            0.631
# ########## Changing sampling mode ##########
# smote               0.656
# bordersmote         0.663
# svmsmote            0.651
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.620
# bordersmote         0.627
# svmsmote            0.625
# ########## Changing sampling mode ##########
# smote               0.648
# bordersmote         0.666
# svmsmote            0.652
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.612
# bordersmote         0.617
# svmsmote            0.629
# ########## Changing sampling mode ##########
# smote               0.657
# bordersmote         0.653
# svmsmote            0.656
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.620
# bordersmote         0.626
# svmsmote            0.632
# ########## Changing sampling mode ##########
# smote               0.660
# bordersmote         0.659
# svmsmote            0.660
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.621
# bordersmote         0.620
# svmsmote            0.625
# ########## Changing sampling mode ##########
# smote               0.654
# bordersmote         0.654
# svmsmote            0.654
#
#
# Name model:      	rf
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.35
# Best score:      	0.6780806054292199
# Dataset size:    	2884, Counter({np.float64(0.0): 1442, np.float64(1.0): 1442})
# Combination:     	_random_bordersmote_rf
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.979     0.934     0.956      1442
#          1.0      0.937     0.980     0.958      1442
#
#     accuracy                          0.957      2884
#    macro avg      0.958     0.957     0.957      2884
# weighted avg      0.958     0.957     0.957      2884
#
# auc macro 0.993
# confusion matrix
# [[1347   95]
#  [  29 1413]]
#               precision    recall  f1-score   support
#
#          0.0      0.424     0.509     0.462       169
#          1.0      0.927     0.900     0.913      1165
#
#     accuracy                          0.850      1334
#    macro avg      0.675     0.704     0.688      1334
# weighted avg      0.863     0.850     0.856      1334
#
# auc macro 0.821
# confusion matrix
# [[  86   83]
#  [ 117 1048]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.648
# bordersmote         0.644
# svmsmote            0.645
# ########## Changing sampling mode ##########
# smote               0.654
# bordersmote         0.648
# svmsmote            0.643
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.648
# bordersmote         0.666
# svmsmote            0.636
# ########## Changing sampling mode ##########
# smote               0.678
# bordersmote         0.681
# svmsmote            0.637
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.648
# bordersmote         0.642
# svmsmote            0.652
# ########## Changing sampling mode ##########
# smote               0.674
# bordersmote         0.681
# svmsmote            0.633
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.661
# bordersmote         0.636
# svmsmote            0.655
# ########## Changing sampling mode ##########
# smote               0.661
# bordersmote         0.676
# svmsmote            0.661
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.627
# bordersmote         0.638
# svmsmote            0.615
# ########## Changing sampling mode ##########
# smote               0.672
# bordersmote         0.672
# svmsmote            0.651
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.659
# bordersmote         0.642
# svmsmote            0.649
# ########## Changing sampling mode ##########
# smote               0.672
# bordersmote         0.658
# svmsmote            0.654
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.636
# bordersmote         0.639
# svmsmote            0.648
# ########## Changing sampling mode ##########
# smote               0.665
# bordersmote         0.663
# svmsmote            0.636
#
#
# Name model:      	adaboost
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.35
# Best score:      	0.6924640476399211
# Dataset size:    	2884, Counter({np.float64(0.0): 1442, np.float64(1.0): 1442})
# Combination:     	_random_smote_adaboost
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.908     0.844     0.875      1442
#          1.0      0.854     0.914     0.883      1442
#
#     accuracy                          0.879      2884
#    macro avg      0.881     0.879     0.879      2884
# weighted avg      0.881     0.879     0.879      2884
#
# auc macro 0.945
# confusion matrix
# [[1217  225]
#  [ 124 1318]]
#               precision    recall  f1-score   support
#
#          0.0      0.408     0.580     0.479       169
#          1.0      0.935     0.878     0.906      1165
#
#     accuracy                          0.840      1334
#    macro avg      0.672     0.729     0.692      1334
# weighted avg      0.868     0.840     0.852      1334
#
# auc macro 0.827
# confusion matrix
# [[  98   71]
#  [ 142 1023]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.638
# bordersmote         0.654
# svmsmote            0.657
# ########## Changing sampling mode ##########
# smote               0.659
# bordersmote         0.646
# svmsmote            0.658
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.633
# bordersmote         0.654
# svmsmote            0.649
# ########## Changing sampling mode ##########
# smote               0.646
# bordersmote         0.652
# svmsmote            0.659
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.638
# bordersmote         0.653
# svmsmote            0.658
# ########## Changing sampling mode ##########
# smote               0.654
# bordersmote         0.630
# svmsmote            0.651
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.644
# bordersmote         0.647
# svmsmote            0.663
# ########## Changing sampling mode ##########
# smote               0.625
# bordersmote         0.623
# svmsmote            0.628
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.644
# bordersmote         0.653
# svmsmote            0.649
# ########## Changing sampling mode ##########
# smote               0.625
# bordersmote         0.623
# svmsmote            0.640
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.630
# bordersmote         0.648
# svmsmote            0.664
# ########## Changing sampling mode ##########
# smote               0.644
# bordersmote         0.640
# svmsmote            0.641
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.634
# bordersmote         0.650
# svmsmote            0.660
# ########## Changing sampling mode ##########
# smote               0.635
# bordersmote         0.604
# svmsmote            0.648
#
#
# Name model:      	nn
# Sampling method: only oversampling
# Best rand_ratio: 	0.35
# Best score:      	0.6700961582315846
# Dataset size:    	6988, Counter({np.float64(1.0): 3494, np.float64(0.0): 3494})
# Combination:     	_random_svmsmote_nn
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.858     0.859     0.858      3494
#          1.0      0.859     0.857     0.858      3494
#
#     accuracy                          0.858      6988
#    macro avg      0.858     0.858     0.858      6988
# weighted avg      0.858     0.858     0.858      6988
#
# auc macro 0.929
# confusion matrix
# [[3002  492]
#  [ 498 2996]]
#               precision    recall  f1-score   support
#
#          0.0      0.353     0.615     0.448       169
#          1.0      0.937     0.836     0.884      1165
#
#     accuracy                          0.808      1334
#    macro avg      0.645     0.726     0.666      1334
# weighted avg      0.863     0.808     0.829      1334
#
# auc macro 0.820
# confusion matrix
# [[104  65]
#  [191 974]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.635
# bordersmote         0.644
# svmsmote            0.636
# ########## Changing sampling mode ##########
# smote               0.656
# bordersmote         0.656
# svmsmote            0.655
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.639
# bordersmote         0.655
# svmsmote            0.641
# ########## Changing sampling mode ##########
# smote               0.658
# bordersmote         0.666
# svmsmote            0.657
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.637
# bordersmote         0.644
# svmsmote            0.636
# ########## Changing sampling mode ##########
# smote               0.660
# bordersmote         0.667
# svmsmote            0.660
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.637
# bordersmote         0.644
# svmsmote            0.636
# ########## Changing sampling mode ##########
# smote               0.670
# bordersmote         0.674
# svmsmote            0.662
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.636
# bordersmote         0.644
# svmsmote            0.641
# ########## Changing sampling mode ##########
# smote               0.673
# bordersmote         0.666
# svmsmote            0.653
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.628
# bordersmote         0.637
# svmsmote            0.637
# ########## Changing sampling mode ##########
# smote               0.678
# bordersmote         0.679
# svmsmote            0.660
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.645
# bordersmote         0.654
# svmsmote            0.640
# ########## Changing sampling mode ##########
# smote               0.666
# bordersmote         0.670
# svmsmote            0.655
#
#
# Name model:      	gb
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.45
# Best score:      	0.6788211562701182
# Dataset size:    	2244, Counter({np.float64(0.0): 1122, np.float64(1.0): 1122})
# Combination:     	_random_bordersmote_gb
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.933     0.881     0.906      1122
#          1.0      0.887     0.937     0.911      1122
#
#     accuracy                          0.909      2244
#    macro avg      0.910     0.909     0.909      2244
# weighted avg      0.910     0.909     0.909      2244
#
# auc macro 0.967
# confusion matrix
# [[ 988  134]
#  [  71 1051]]
#               precision    recall  f1-score   support
#
#          0.0      0.383     0.609     0.470       169
#          1.0      0.938     0.858     0.896      1165
#
#     accuracy                          0.826      1334
#    macro avg      0.660     0.733     0.683      1334
# weighted avg      0.868     0.826     0.842      1334
#
# auc macro 0.815
# confusion matrix
# [[103  66]
#  [166 999]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.605
# bordersmote         0.606
# svmsmote            0.625
# ########## Changing sampling mode ##########
# smote               0.585
# bordersmote         0.585
# svmsmote            0.602
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.595
# bordersmote         0.606
# svmsmote            0.620
# ########## Changing sampling mode ##########
# smote               0.571
# bordersmote         0.562
# svmsmote            0.597
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.613
# bordersmote         0.598
# svmsmote            0.619
# ########## Changing sampling mode ##########
# smote               0.559
# bordersmote         0.545
# svmsmote            0.558
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.607
# bordersmote         0.608
# svmsmote            0.618
# ########## Changing sampling mode ##########
# smote               0.563
# bordersmote         0.517
# svmsmote            0.579
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.603
# bordersmote         0.611
# svmsmote            0.619
# ########## Changing sampling mode ##########
# smote               0.547
# bordersmote         0.523
# svmsmote            0.548
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.602
# bordersmote         0.615
# svmsmote            0.622
# ########## Changing sampling mode ##########
# smote               0.531
# bordersmote         0.513
# svmsmote            0.543
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.600
# bordersmote         0.595
# svmsmote            0.613
# ########## Changing sampling mode ##########
# smote               0.535
# bordersmote         0.514
# svmsmote            0.562
#
#
# Name model:      	xgb
# Sampling method: only oversampling
# Best rand_ratio: 	0.25
# Best score:      	0.632732025884413
# Dataset size:    	6988, Counter({np.float64(1.0): 3494, np.float64(0.0): 3494})
# Combination:     	_random_svmsmote_xgb
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.816     0.937     0.872      3494
#          1.0      0.926     0.788     0.852      3494
#
#     accuracy                          0.863      6988
#    macro avg      0.871     0.863     0.862      6988
# weighted avg      0.871     0.863     0.862      6988
#
# auc macro 0.954
# confusion matrix
# [[3273  221]
#  [ 739 2755]]
#               precision    recall  f1-score   support
#
#          0.0      0.300     0.728     0.425       169
#          1.0      0.950     0.754     0.841      1165
#
#     accuracy                          0.750      1334
#    macro avg      0.625     0.741     0.633      1334
# weighted avg      0.868     0.750     0.788      1334
#
# auc macro 0.810
# confusion matrix
# [[123  46]
#  [287 878]]

# %%
from auto_export_notebook import export_current_notebook


html_path = export_current_notebook(
    globals(),
    wait_for_disk_save=True,   # wait for Auto Save
    wait_timeout_sec=8.0
)
print("Exported to:", html_path)
# Out:
# Exported to: /home/ileniag/buzi_ml4cad_0/exported_notebooks/3.1_data_sampling_27features_20251026_140035.html
