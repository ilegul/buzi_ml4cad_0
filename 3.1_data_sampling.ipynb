# %%
import os
print("Current directory:", os.getcwd())
print("Git branch:", os.popen('git branch --show-current').read().strip())
# Out:
# Current directory: /home/ileniag/buzi_ml4cad_noncvd
# Git branch: noncvd-7y-alive

# %%
# This notebook is used to
# 1. Refine the classifiers to mitigate data imbalance
# 2. Create ensemble classifier
# 3. Perform feature ablation

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import copy
from joblib import dump, load

plt.style.use('bmh')
mpl.rcParams.update({
    "grid.linestyle" : "dashed",
    "axes.facecolor" : "white",
    "axes.spines.top" : False,
    "axes.spines.right" : False,
    "legend.frameon" : False,
    "figure.figsize" : (8, 5),
    "figure.dpi" : 300,
})

# suppress sklearn deprecated warnings
import warnings
def warn(*args, **kwargs): pass
warnings.warn = warn

# %%
# TODO make test for dataset with creatina column
# Dataset without thyroid = 18 features (including survive7y)
# Dataset with thyroid = 27 features (including survive7y)
# With columns that have missing values, 23 and 32
# Default 18
n_features = 27
extra_path = n_features != 27 and n_features != 18
dropped_na_key = "dropped_na/"
mean_key = "mean/"
path = f"data/{n_features}features/{mean_key if extra_path else '' }"
path_models = f"models/{n_features}features/{mean_key if extra_path else '' }"
path_images = f"figures/{n_features}features/{mean_key if extra_path else '' }"
output_models = f"models_output/{n_features}features/{mean_key if extra_path else '' }"
print(path_models)
print(path)
# Out:
# models/27features/
# data/27features/

# %% [markdown]
# ### Sampling
# Oversample and undersample methods to mitigate data imbalance

# %%
# Load Data for sampling
df_train = pd.read_csv(f"{path}train.csv", index_col=0)
df_valid = pd.read_csv(f"{path}valid.csv", index_col=0)
df_test = pd.read_csv(f"{path}test.csv", index_col=0)
print(len(df_train)+len(df_valid)+len(df_test))
feat_names = list(df_train.columns)
train, valid, test = df_train.to_numpy(), df_valid.to_numpy(), df_test.to_numpy()
X_train, y_train = train[:, :-1], train[:, -1]
X_valid, y_valid = valid[:, :-1], valid[:, -1]
X_test, y_test = test[:, :-1], test[:, -1]

from utils import get_preprocess_std_num
preprocess_std = get_preprocess_std_num(feat_names)


# Preprocessed ready-to-use train and valid set
process_tmp = preprocess_std.fit(X_train)
X_train_std = process_tmp.transform(X_train)
X_valid_std = process_tmp.transform(X_valid)
# Out:
# 7018

# %%
from imblearn.over_sampling import SMOTE, BorderlineSMOTE, SVMSMOTE
from collections import Counter
from train import evaluate
from utils import datasetSampler
from functools import partial
from train import evaluate
from contextlib import redirect_stdout
# Over sample to 50/
overs = [
    ("smote", SMOTE(sampling_strategy=1.0, k_neighbors=1)),
    ("bordersmote", BorderlineSMOTE(sampling_strategy=1.0, k_neighbors=1)),
    ("svmsmote", SVMSMOTE(sampling_strategy=1.0, k_neighbors=1)), 
    # ADASYN(sampling_strategy=1.0, n_neighbors=1)
]

sampler = partial(
    datasetSampler,
    # missing parameters: model, overSampler, sampling_strategy
    X_train=X_train,
    y_train=y_train,
    X_valid=X_valid,
    y_valid=y_valid,
    useUnderSampler = False
)
random_ratio = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
name_models = ["lr", "svc", "knn", "rf", "adaboost", "nn", "gb", "xgb"]
for name in name_models:
    best_k = 0
    best_over = ""
    best_score = 0
    best_random = 0
    best_model = None
    file_name = ""
    sampling_method = ""
    best_X, best_y = None, None

    for r in random_ratio:
        print("-------------------------------------------------")
        print(f"{'Oversample':<20}{'Score':<20}Random {r} Name {name}")
        print("-------------------------------------------------")
        for underSampler in range(1,3):
            print(f"########## Changing sampling mode ##########")
            for name_over, over in overs:
                for k in range(2, 5):
                    model = load(path_models+f"{name}.joblib")
                    over.set_params(k_neighbors=k)
                    result = sampler(
                        model_name= name,
                        model = model,
                        overSampler = over,
                        sampling_strategy = r,
                        useUnderSampler = True if underSampler == 2 else False
                    )
                    score = result[0]
                    X_train_sample = result[1]
                    y_train_sample = result[2]
                    model = result[3]
                    if score > best_score:
                        best_k = k
                        best_over = name_over
                        best_score = score
                        best_random = r
                        best_model = copy.deepcopy(model)
                        sampling_method = "only oversampling" if underSampler == 1 else "undersampling + oversampling"
                        suffix = "_only_oversampling" if underSampler == 1 else "_sampling"
                        file_name = output_models.replace("models_output/", '').replace("/","") + suffix + ".txt"
                        best_X = X_train_sample
                        best_y = y_train_sample
                #in this case the score is the last score computed with k = 4
                print(f'{name_over:<20}{score:.3f}')

    # Save the dataset and model
    combination = f"_random_{best_over}_{name}"
    tmp = np.concatenate((best_X, np.expand_dims(best_y, 1)), axis=1)
    tmp = pd.DataFrame(tmp, columns=feat_names)

    # Current model's statistics
    print("\n")
    print(f"Name model:      \t{name}")
    print(f"Sampling method: {sampling_method }")
    print(f"Best rand_ratio: \t{best_random}")
    print(f"Best score:      \t{best_score}")
    print(f"Dataset size:    \t{len(best_y)}, {Counter(best_y)}")
    print(f"Combination:     \t{combination}")
    print("\n\n")

    # Evaluate the best model, save the data and the best model
    evaluate(best_model, best_X, best_y)
    evaluate(best_model, X_valid, y_valid)
    tmp.to_csv(path+f"train{combination}.csv")
    dump(best_model, path_models+f"{name}{combination}.joblib")
    with open(f"{output_models}{file_name}", 'a+') as f:
            with redirect_stdout(f):
                print (f"####################   {name}    #########################")
                print("Testing on training set:")
                evaluate(best_model, best_X, best_y)
                print("Testing on validation set:")
                evaluate(best_model, X_valid, y_valid)
                print("Parameters: {0}".format(model.get_params()))
                print (f"####################   {name}  END   #########################")
# Out:
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.590
# bordersmote         0.602
# svmsmote            0.617
# ########## Changing sampling mode ##########
# smote               0.630
# bordersmote         0.616
# svmsmote            0.617
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.548
# bordersmote         0.616
# svmsmote            0.634
# ########## Changing sampling mode ##########
# smote               0.609
# bordersmote         0.605
# svmsmote            0.565
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.565
# bordersmote         0.613
# svmsmote            0.641
# ########## Changing sampling mode ##########
# smote               0.604
# bordersmote         0.573
# svmsmote            0.563
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.553
# bordersmote         0.614
# svmsmote            0.637
# ########## Changing sampling mode ##########
# smote               0.586
# bordersmote         0.549
# svmsmote            0.604
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.608
# bordersmote         0.599
# svmsmote            0.619
# ########## Changing sampling mode ##########
# smote               0.579
# bordersmote         0.614
# svmsmote            0.625
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.596
# bordersmote         0.626
# svmsmote            0.636
# ########## Changing sampling mode ##########
# smote               0.567
# bordersmote         0.617
# svmsmote            0.602
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.575
# bordersmote         0.617
# svmsmote            0.650
# ########## Changing sampling mode ##########
# smote               0.611
# bordersmote         0.557
# svmsmote            0.591
#
#
# Name model:      	lr
# Sampling method: only oversampling
# Best rand_ratio: 	0.2
# Best score:      	0.655044053706236
# Dataset size:    	7410, Counter({np.float64(1.0): 3705, np.float64(0.0): 3705})
# Combination:     	_random_svmsmote_lr
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.892     0.837     0.864      3705
#          1.0      0.846     0.899     0.872      3705
#
#     accuracy                          0.868      7410
#    macro avg      0.869     0.868     0.868      7410
# weighted avg      0.869     0.868     0.868      7410
#
# auc macro 0.942
# confusion matrix
# [[3100  605]
#  [ 375 3330]]
#               precision    recall  f1-score   support
#
#          0.0      0.371     0.491     0.422       169
#          1.0      0.927     0.886     0.906      1235
#
#     accuracy                          0.838      1404
#    macro avg      0.649     0.688     0.664      1404
# weighted avg      0.860     0.838     0.848      1404
#
# auc macro 0.813
# confusion matrix
# [[  83   86]
#  [ 141 1094]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.571
# bordersmote         0.521
# svmsmote            0.463
# ########## Changing sampling mode ##########
# smote               0.527
# bordersmote         0.374
# svmsmote            0.588
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.596
# bordersmote         0.587
# svmsmote            0.599
# ########## Changing sampling mode ##########
# smote               0.413
# bordersmote         0.611
# svmsmote            0.488
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.494
# bordersmote         0.367
# svmsmote            0.573
# ########## Changing sampling mode ##########
# smote               0.577
# bordersmote         0.625
# svmsmote            0.487
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.557
# bordersmote         0.590
# svmsmote            0.568
# ########## Changing sampling mode ##########
# smote               0.592
# bordersmote         0.578
# svmsmote            0.602
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.590
# bordersmote         0.548
# svmsmote            0.563
# ########## Changing sampling mode ##########
# smote               0.589
# bordersmote         0.562
# svmsmote            0.518
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.526
# bordersmote         0.592
# svmsmote            0.609
# ########## Changing sampling mode ##########
# smote               0.593
# bordersmote         0.598
# svmsmote            0.622
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.579
# bordersmote         0.596
# svmsmote            0.595
# ########## Changing sampling mode ##########
# smote               0.585
# bordersmote         0.624
# svmsmote            0.639
#
#
# Name model:      	svc
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.5
# Best score:      	0.6386267683875269
# Dataset size:    	2020, Counter({np.float64(0.0): 1010, np.float64(1.0): 1010})
# Combination:     	_random_svmsmote_svc
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.842     0.754     0.796      1010
#          1.0      0.778     0.858     0.816      1010
#
#     accuracy                          0.806      2020
#    macro avg      0.810     0.806     0.806      2020
# weighted avg      0.810     0.806     0.806      2020
#
# auc macro 0.875
# confusion matrix
# [[762 248]
#  [143 867]]
#               precision    recall  f1-score   support
#
#          0.0      0.313     0.538     0.396       169
#          1.0      0.930     0.838     0.882      1235
#
#     accuracy                          0.802      1404
#    macro avg      0.621     0.688     0.639      1404
# weighted avg      0.856     0.802     0.823      1404
#
# auc macro 0.790
# confusion matrix
# [[  91   78]
#  [ 200 1035]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.545
# bordersmote         0.558
# svmsmote            0.585
# ########## Changing sampling mode ##########
# smote               0.527
# bordersmote         0.547
# svmsmote            0.574
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.545
# bordersmote         0.561
# svmsmote            0.575
# ########## Changing sampling mode ##########
# smote               0.515
# bordersmote         0.519
# svmsmote            0.576
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.546
# bordersmote         0.561
# svmsmote            0.578
# ########## Changing sampling mode ##########
# smote               0.525
# bordersmote         0.516
# svmsmote            0.572
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.543
# bordersmote         0.559
# svmsmote            0.592
# ########## Changing sampling mode ##########
# smote               0.515
# bordersmote         0.506
# svmsmote            0.530
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.551
# bordersmote         0.557
# svmsmote            0.588
# ########## Changing sampling mode ##########
# smote               0.510
# bordersmote         0.498
# svmsmote            0.537
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.548
# bordersmote         0.566
# svmsmote            0.589
# ########## Changing sampling mode ##########
# smote               0.507
# bordersmote         0.502
# svmsmote            0.531
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.549
# bordersmote         0.561
# svmsmote            0.582
# ########## Changing sampling mode ##########
# smote               0.510
# bordersmote         0.492
# svmsmote            0.539
#
#
# Name model:      	knn
# Sampling method: only oversampling
# Best rand_ratio: 	0.45
# Best score:      	0.6155693163149247
# Dataset size:    	7410, Counter({np.float64(1.0): 3705, np.float64(0.0): 3705})
# Combination:     	_random_svmsmote_knn
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.875     0.986     0.927      3705
#          1.0      0.984     0.860     0.917      3705
#
#     accuracy                          0.923      7410
#    macro avg      0.929     0.923     0.922      7410
# weighted avg      0.929     0.923     0.922      7410
#
# auc macro 0.993
# confusion matrix
# [[3652   53]
#  [ 520 3185]]
#               precision    recall  f1-score   support
#
#          0.0      0.279     0.533     0.366       169
#          1.0      0.927     0.811     0.865      1235
#
#     accuracy                          0.778      1404
#    macro avg      0.603     0.672     0.616      1404
# weighted avg      0.849     0.778     0.805      1404
#
# auc macro 0.711
# confusion matrix
# [[  90   79]
#  [ 233 1002]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.634
# bordersmote         0.632
# svmsmote            0.649
# ########## Changing sampling mode ##########
# smote               0.671
# bordersmote         0.666
# svmsmote            0.678
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.631
# bordersmote         0.624
# svmsmote            0.651
# ########## Changing sampling mode ##########
# smote               0.675
# bordersmote         0.665
# svmsmote            0.672
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.633
# bordersmote         0.624
# svmsmote            0.658
# ########## Changing sampling mode ##########
# smote               0.668
# bordersmote         0.674
# svmsmote            0.673
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.634
# bordersmote         0.624
# svmsmote            0.654
# ########## Changing sampling mode ##########
# smote               0.677
# bordersmote         0.650
# svmsmote            0.666
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.628
# bordersmote         0.620
# svmsmote            0.654
# ########## Changing sampling mode ##########
# smote               0.658
# bordersmote         0.665
# svmsmote            0.653
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.624
# bordersmote         0.615
# svmsmote            0.660
# ########## Changing sampling mode ##########
# smote               0.662
# bordersmote         0.662
# svmsmote            0.649
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.631
# bordersmote         0.610
# svmsmote            0.653
# ########## Changing sampling mode ##########
# smote               0.654
# bordersmote         0.651
# svmsmote            0.648
#
#
# Name model:      	rf
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.25
# Best score:      	0.6786229110166838
# Dataset size:    	4040, Counter({np.float64(0.0): 2020, np.float64(1.0): 2020})
# Combination:     	_random_svmsmote_rf
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.975     0.936     0.955      2020
#          1.0      0.938     0.976     0.957      2020
#
#     accuracy                          0.956      4040
#    macro avg      0.956     0.956     0.956      4040
# weighted avg      0.956     0.956     0.956      4040
#
# auc macro 0.993
# confusion matrix
# [[1890  130]
#  [  49 1971]]
#               precision    recall  f1-score   support
#
#          0.0      0.423     0.473     0.447       169
#          1.0      0.927     0.912     0.919      1235
#
#     accuracy                          0.859      1404
#    macro avg      0.675     0.693     0.683      1404
# weighted avg      0.866     0.859     0.862      1404
#
# auc macro 0.818
# confusion matrix
# [[  80   89]
#  [ 109 1126]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.622
# bordersmote         0.667
# svmsmote            0.653
# ########## Changing sampling mode ##########
# smote               0.663
# bordersmote         0.665
# svmsmote            0.644
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.647
# bordersmote         0.651
# svmsmote            0.643
# ########## Changing sampling mode ##########
# smote               0.658
# bordersmote         0.667
# svmsmote            0.644
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.638
# bordersmote         0.645
# svmsmote            0.653
# ########## Changing sampling mode ##########
# smote               0.669
# bordersmote         0.666
# svmsmote            0.647
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.635
# bordersmote         0.658
# svmsmote            0.656
# ########## Changing sampling mode ##########
# smote               0.667
# bordersmote         0.671
# svmsmote            0.640
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.645
# bordersmote         0.656
# svmsmote            0.648
# ########## Changing sampling mode ##########
# smote               0.649
# bordersmote         0.674
# svmsmote            0.645
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.642
# bordersmote         0.645
# svmsmote            0.636
# ########## Changing sampling mode ##########
# smote               0.657
# bordersmote         0.650
# svmsmote            0.646
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.639
# bordersmote         0.658
# svmsmote            0.642
# ########## Changing sampling mode ##########
# smote               0.658
# bordersmote         0.647
# svmsmote            0.645
#
#
# Name model:      	adaboost
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.3
# Best score:      	0.6808409732118645
# Dataset size:    	3366, Counter({np.float64(0.0): 1683, np.float64(1.0): 1683})
# Combination:     	_random_bordersmote_adaboost
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.916     0.847     0.880      1683
#          1.0      0.857     0.922     0.889      1683
#
#     accuracy                          0.884      3366
#    macro avg      0.887     0.884     0.884      3366
# weighted avg      0.887     0.884     0.884      3366
#
# auc macro 0.952
# confusion matrix
# [[1425  258]
#  [ 131 1552]]
#               precision    recall  f1-score   support
#
#          0.0      0.424     0.462     0.442       169
#          1.0      0.925     0.914     0.920      1235
#
#     accuracy                          0.860      1404
#    macro avg      0.675     0.688     0.681      1404
# weighted avg      0.865     0.860     0.862      1404
#
# auc macro 0.817
# confusion matrix
# [[  78   91]
#  [ 106 1129]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.639
# bordersmote         0.645
# svmsmote            0.660
# ########## Changing sampling mode ##########
# smote               0.636
# bordersmote         0.634
# svmsmote            0.648
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.641
# bordersmote         0.650
# svmsmote            0.641
# ########## Changing sampling mode ##########
# smote               0.631
# bordersmote         0.633
# svmsmote            0.643
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.635
# bordersmote         0.642
# svmsmote            0.656
# ########## Changing sampling mode ##########
# smote               0.615
# bordersmote         0.626
# svmsmote            0.642
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.643
# bordersmote         0.648
# svmsmote            0.659
# ########## Changing sampling mode ##########
# smote               0.640
# bordersmote         0.620
# svmsmote            0.643
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.640
# bordersmote         0.649
# svmsmote            0.654
# ########## Changing sampling mode ##########
# smote               0.614
# bordersmote         0.606
# svmsmote            0.638
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.643
# bordersmote         0.637
# svmsmote            0.646
# ########## Changing sampling mode ##########
# smote               0.629
# bordersmote         0.603
# svmsmote            0.619
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.649
# bordersmote         0.642
# svmsmote            0.667
# ########## Changing sampling mode ##########
# smote               0.619
# bordersmote         0.589
# svmsmote            0.614
#
#
# Name model:      	nn
# Sampling method: only oversampling
# Best rand_ratio: 	0.5
# Best score:      	0.6671281233274489
# Dataset size:    	7410, Counter({np.float64(1.0): 3705, np.float64(0.0): 3705})
# Combination:     	_random_svmsmote_nn
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.917     0.945     0.931      3705
#          1.0      0.944     0.914     0.929      3705
#
#     accuracy                          0.930      7410
#    macro avg      0.930     0.930     0.930      7410
# weighted avg      0.930     0.930     0.930      7410
#
# auc macro 0.977
# confusion matrix
# [[3503  202]
#  [ 319 3386]]
#               precision    recall  f1-score   support
#
#          0.0      0.382     0.538     0.447       169
#          1.0      0.933     0.881     0.906      1235
#
#     accuracy                          0.840      1404
#    macro avg      0.658     0.710     0.677      1404
# weighted avg      0.867     0.840     0.851      1404
#
# auc macro 0.776
# confusion matrix
# [[  91   78]
#  [ 147 1088]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.642
# bordersmote         0.644
# svmsmote            0.669
# ########## Changing sampling mode ##########
# smote               0.663
# bordersmote         0.668
# svmsmote            0.674
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.648
# bordersmote         0.639
# svmsmote            0.674
# ########## Changing sampling mode ##########
# smote               0.657
# bordersmote         0.669
# svmsmote            0.669
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.657
# bordersmote         0.644
# svmsmote            0.668
# ########## Changing sampling mode ##########
# smote               0.662
# bordersmote         0.659
# svmsmote            0.662
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.652
# bordersmote         0.653
# svmsmote            0.670
# ########## Changing sampling mode ##########
# smote               0.647
# bordersmote         0.650
# svmsmote            0.667
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.646
# bordersmote         0.656
# svmsmote            0.662
# ########## Changing sampling mode ##########
# smote               0.658
# bordersmote         0.658
# svmsmote            0.657
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.647
# bordersmote         0.650
# svmsmote            0.664
# ########## Changing sampling mode ##########
# smote               0.646
# bordersmote         0.648
# svmsmote            0.661
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.662
# bordersmote         0.648
# svmsmote            0.665
# ########## Changing sampling mode ##########
# smote               0.651
# bordersmote         0.651
# svmsmote            0.650
#
#
# Name model:      	gb
# Sampling method: only oversampling
# Best rand_ratio: 	0.5
# Best score:      	0.675524517137314
# Dataset size:    	7410, Counter({np.float64(1.0): 3705, np.float64(0.0): 3705})
# Combination:     	_random_svmsmote_gb
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.983     0.933     0.957      3705
#          1.0      0.936     0.984     0.960      3705
#
#     accuracy                          0.959      7410
#    macro avg      0.960     0.959     0.959      7410
# weighted avg      0.960     0.959     0.959      7410
#
# auc macro 0.990
# confusion matrix
# [[3456  249]
#  [  58 3647]]
#               precision    recall  f1-score   support
#
#          0.0      0.534     0.367     0.435       169
#          1.0      0.917     0.956     0.936      1235
#
#     accuracy                          0.885      1404
#    macro avg      0.726     0.662     0.686      1404
# weighted avg      0.871     0.885     0.876      1404
#
# auc macro 0.802
# confusion matrix
# [[  62  107]
#  [  54 1181]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.666
# bordersmote         0.667
# svmsmote            0.652
# ########## Changing sampling mode ##########
# smote               0.650
# bordersmote         0.637
# svmsmote            0.632
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.661
# bordersmote         0.665
# svmsmote            0.659
# ########## Changing sampling mode ##########
# smote               0.613
# bordersmote         0.624
# svmsmote            0.616
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.652
# bordersmote         0.661
# svmsmote            0.652
# ########## Changing sampling mode ##########
# smote               0.614
# bordersmote         0.606
# svmsmote            0.591
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.658
# bordersmote         0.661
# svmsmote            0.663
# ########## Changing sampling mode ##########
# smote               0.608
# bordersmote         0.594
# svmsmote            0.594
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.665
# bordersmote         0.660
# svmsmote            0.659
# ########## Changing sampling mode ##########
# smote               0.594
# bordersmote         0.570
# svmsmote            0.560
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.646
# bordersmote         0.655
# svmsmote            0.668
# ########## Changing sampling mode ##########
# smote               0.584
# bordersmote         0.565
# svmsmote            0.579
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.666
# bordersmote         0.662
# svmsmote            0.650
# ########## Changing sampling mode ##########
# smote               0.572
# bordersmote         0.555
# svmsmote            0.559
#
#
# Name model:      	xgb
# Sampling method: only oversampling
# Best rand_ratio: 	0.2
# Best score:      	0.669940548966145
# Dataset size:    	7410, Counter({np.float64(1.0): 3705, np.float64(0.0): 3705})
# Combination:     	_random_bordersmote_xgb
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.873     0.951     0.910      3705
#          1.0      0.946     0.862     0.902      3705
#
#     accuracy                          0.906      7410
#    macro avg      0.910     0.906     0.906      7410
# weighted avg      0.910     0.906     0.906      7410
#
# auc macro 0.978
# confusion matrix
# [[3524  181]
#  [ 512 3193]]
#               precision    recall  f1-score   support
#
#          0.0      0.357     0.592     0.445       169
#          1.0      0.939     0.854     0.894      1235
#
#     accuracy                          0.823      1404
#    macro avg      0.648     0.723     0.670      1404
# weighted avg      0.869     0.823     0.840      1404
#
# auc macro 0.813
# confusion matrix
# [[ 100   69]
#  [ 180 1055]]

# %%
from auto_export_notebook import export_current_notebook


html_path = export_current_notebook(
    globals(),
    wait_for_disk_save=True,   # wait for Auto Save
    wait_timeout_sec=8.0
)
print("Exported to:", html_path)
# Out:
# Exported to: /home/ileniag/buzi_ml4cad_noncvd/exported_notebooks/3.1_data_sampling_27features_20251028_123023.html
